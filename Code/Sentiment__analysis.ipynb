# %% [markdown]
# # LLM

# %% [markdown]
# ## Import Data

# %%
import numpy as np
import pandas as pd

# %%
# Load the CSV file into a DataFrame with the correct encoding
decentraland= pd.read_csv('https://raw.githubusercontent.com/Xintong1122/KDD/main/Data/Decentraland_general.csv', encoding='ISO-8859-1')

# Assume decentraland is the DataFrame you want to remove unnamed columns from
decentraland = decentraland.loc[:, ~decentraland.columns.str.startswith('Unnamed:')]

# %%
# Date format change
decentraland['Date'] = pd.to_datetime(decentraland['Date'], format='%Y-%m-%dT%H:%M:%S.%f%z')
decentraland['Date'] = decentraland['Date'].dt.strftime('%m/%d/%Y %I:%M %p')

# %%
decentraland.head()
# Out:
#        AuthorID              Author                 Date  \
# 0  1.460000e+17           chartguy.  01/01/2024 05:56 AM
# 1  1.020000e+18   Decentraland#7255  01/01/2024 08:00 AM
# 2  1.030000e+18  toxicwaifu.dcl.eth  01/01/2024 08:01 AM
# 3  8.740000e+17        cheddarqueso  01/01/2024 08:23 AM
# 4  8.580000e+17      help_center017  01/01/2024 12:11 PM
#
#                                              Content Attachments  \
# 0                                                 Hi         NaN
# 1                                                NaN         NaN
# 2                Happy New Year from Germany â¨ð         NaN
# 3  Happy New Year DCL fam and team. I am thankful...         NaN
# 4                                            Welcome         NaN
#
#              Reactions
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3  ð (2),â¤ï¸ (1)
# 4                  NaN

# %%
decentraland.tail()
# Out:
#           AuthorID             Author                 Date  \
# 2066  3.500000e+17            .vitsky  06/13/2024 11:17 PM
# 2067  7.810000e+17        eldanak_dcl  06/14/2024 01:24 AM
# 2068  1.020000e+18  Decentraland#7255  06/14/2024 08:00 AM
# 2069  3.990000e+17         cybermike.  06/14/2024 04:51 PM
# 2070  1.020000e+18  Decentraland#7255  06/15/2024 08:00 AM
#
#                                                 Content Attachments  \
# 2066  You can buy lands on our Marketplace ð http...         NaN
# 2067  # ð¥ **Feature Focus Thursday** ð¥\n\nWe w...         NaN
# 2068                                                NaN         NaN
# 2069                                  @Kaze_no_Kai scam         NaN
# 2070                                                NaN         NaN
#
#                 Reactions
# 2066                  NaN
# 2067             ð¥ (3)
# 2068                  NaN
# 2069  â¤ï¸ (3),ð (3)
# 2070                  NaN

# %% [markdown]
# ## Text Processing

# %%
# Delete blank rows in the "Content" column.
decentraland_cleaned = decentraland.dropna(subset=['Content'])

# Save the cleaned DataFrame to a new CSV file
decentraland_cleaned.to_csv('message_cleaned.csv', index=False)

# %% [markdown]
# # Sentiment Analysis using LLM

# %% [markdown]
# ## Sentiment Label and Sentiment Score

# %%
import pandas as pd
from transformers import AutoTokenizer

# Read CSV file from GitHub
url = 'https://raw.githubusercontent.com/Xintong1122/KDD/main/Data/message_cleaned.csv'
df = pd.read_csv(url)

# Extract data from "Content" column
content_data = df['Content'].tolist()

# Load the tokenizer
model_name = "cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Maximum sequence length for the model
max_length = 512

# Filter out texts longer than max_length
filtered_content_data = []
filtered_indices = []

for i, text in enumerate(content_data):
    tokens = tokenizer.encode(text, max_length=max_length, truncation=True)
    if len(tokens) <= max_length:
        filtered_content_data.append(text)
        filtered_indices.append(i)
    print(f"Text length: {len(tokens)}, included: {len(tokens) <= max_length}")

# Create a new DataFrame with the filtered data
filtered_df = df.iloc[filtered_indices].copy()

# Save the filtered data to a new CSV file
filtered_df.to_csv('filtered_message.csv', index=False)
# Out:
# Text length: 3, included: True
# Text length: 19, included: True
# Text length: 107, included: True
# Text length: 3, included: True
# Text length: 13, included: True
# Text length: 42, included: True
# Text length: 57, included: True
# Text length: 15, included: True
# Text length: 7, included: True
# Text length: 15, included: True
# Text length: 62, included: True
# Text length: 7, included: True
# Text length: 6, included: True
# Text length: 23, included: True
# Text length: 71, included: True
# Text length: 10, included: True
# Text length: 75, included: True
# Text length: 8, included: True
# Text length: 5, included: True
# Text length: 12, included: True
# Text length: 30, included: True
# Text length: 5, included: True
# Text length: 7, included: True
# Text length: 61, included: True
# Text length: 68, included: True
# Text length: 9, included: True
# Text length: 32, included: True
# Text length: 15, included: True
# Text length: 22, included: True
# Text length: 16, included: True
# Text length: 10, included: True
# Text length: 80, included: True
# Text length: 4, included: True
# Text length: 8, included: True
# Text length: 5, included: True
# Text length: 4, included: True
# Text length: 8, included: True
# Text length: 97, included: True
# Text length: 22, included: True
# Text length: 44, included: True
# Text length: 13, included: True
# Text length: 12, included: True
# Text length: 32, included: True
# Text length: 69, included: True
# Text length: 18, included: True
# Text length: 13, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 12, included: True
# Text length: 3, included: True
# Text length: 22, included: True
# Text length: 8, included: True
# Text length: 22, included: True
# Text length: 8, included: True
# Text length: 53, included: True
# Text length: 50, included: True
# Text length: 33, included: True
# Text length: 27, included: True
# Text length: 43, included: True
# Text length: 73, included: True
# Text length: 63, included: True
# Text length: 72, included: True
# Text length: 13, included: True
# Text length: 29, included: True
# Text length: 70, included: True
# Text length: 13, included: True
# Text length: 91, included: True
# Text length: 45, included: True
# Text length: 65, included: True
# Text length: 16, included: True
# Text length: 85, included: True
# Text length: 5, included: True
# Text length: 28, included: True
# Text length: 66, included: True
# Text length: 28, included: True
# Text length: 34, included: True
# Text length: 12, included: True
# Text length: 16, included: True
# Text length: 26, included: True
# Text length: 17, included: True
# Text length: 26, included: True
# Text length: 24, included: True
# Text length: 28, included: True
# Text length: 55, included: True
# Text length: 13, included: True
# Text length: 136, included: True
# Text length: 75, included: True
# Text length: 10, included: True
# Text length: 54, included: True
# Text length: 22, included: True
# Text length: 39, included: True
# Text length: 60, included: True
# Text length: 34, included: True
# Text length: 5, included: True
# Text length: 8, included: True
# Text length: 28, included: True
# Text length: 25, included: True
# Text length: 93, included: True
# Text length: 88, included: True
# Text length: 6, included: True
# Text length: 32, included: True
# Text length: 23, included: True
# Text length: 25, included: True
# Text length: 36, included: True
# Text length: 3, included: True
# Text length: 15, included: True
# Text length: 18, included: True
# Text length: 13, included: True
# Text length: 7, included: True
# Text length: 47, included: True
# Text length: 88, included: True
# Text length: 46, included: True
# Text length: 87, included: True
# Text length: 68, included: True
# Text length: 15, included: True
# Text length: 100, included: True
# Text length: 49, included: True
# Text length: 3, included: True
# Text length: 10, included: True
# Text length: 119, included: True
# Text length: 25, included: True
# Text length: 61, included: True
# Text length: 90, included: True
# Text length: 68, included: True
# Text length: 69, included: True
# Text length: 121, included: True
# Text length: 35, included: True
# Text length: 74, included: True
# Text length: 37, included: True
# Text length: 29, included: True
# Text length: 5, included: True
# Text length: 27, included: True
# Text length: 5, included: True
# Text length: 23, included: True
# Text length: 4, included: True
# Text length: 8, included: True
# Text length: 3, included: True
# Text length: 54, included: True
# Text length: 50, included: True
# Text length: 65, included: True
# Text length: 9, included: True
# Text length: 3, included: True
# Text length: 63, included: True
# Text length: 23, included: True
# Text length: 7, included: True
# Text length: 6, included: True
# Text length: 23, included: True
# Text length: 13, included: True
# Text length: 29, included: True
# Text length: 112, included: True
# Text length: 19, included: True
# Text length: 5, included: True
# Text length: 98, included: True
# Text length: 21, included: True
# Text length: 28, included: True
# Text length: 360, included: True
# Text length: 98, included: True
# Text length: 32, included: True
# Text length: 13, included: True
# Text length: 7, included: True
# Text length: 7, included: True
# Text length: 64, included: True
# Text length: 73, included: True
# Text length: 32, included: True
# Text length: 28, included: True
# Text length: 53, included: True
# Text length: 22, included: True
# Text length: 23, included: True
# Text length: 29, included: True
# Text length: 96, included: True
# Text length: 73, included: True
# Text length: 5, included: True
# Text length: 48, included: True
# Text length: 4, included: True
# Text length: 93, included: True
# Text length: 30, included: True
# Text length: 3, included: True
# Text length: 39, included: True
# Text length: 6, included: True
# Text length: 31, included: True
# Text length: 20, included: True
# Text length: 45, included: True
# Text length: 31, included: True
# Text length: 3, included: True
# Text length: 6, included: True
# Text length: 7, included: True
# Text length: 12, included: True
# Text length: 25, included: True
# Text length: 20, included: True
# Text length: 14, included: True
# Text length: 25, included: True
# Text length: 13, included: True
# Text length: 24, included: True
# Text length: 7, included: True
# Text length: 9, included: True
# Text length: 18, included: True
# Text length: 36, included: True
# Text length: 19, included: True
# Text length: 43, included: True
# Text length: 25, included: True
# Text length: 8, included: True
# Text length: 35, included: True
# Text length: 44, included: True
# Text length: 86, included: True
# Text length: 8, included: True
# Text length: 8, included: True
# Text length: 32, included: True
# Text length: 4, included: True
# Text length: 9, included: True
# Text length: 108, included: True
# Text length: 65, included: True
# Text length: 145, included: True
# Text length: 89, included: True
# Text length: 33, included: True
# Text length: 20, included: True
# Text length: 3, included: True
# Text length: 15, included: True
# Text length: 4, included: True
# Text length: 29, included: True
# Text length: 86, included: True
# Text length: 29, included: True
# Text length: 4, included: True
# Text length: 69, included: True
# Text length: 47, included: True
# Text length: 25, included: True
# Text length: 19, included: True
# Text length: 125, included: True
# Text length: 38, included: True
# Text length: 13, included: True
# Text length: 39, included: True
# Text length: 11, included: True
# Text length: 58, included: True
# Text length: 19, included: True
# Text length: 60, included: True
# Text length: 15, included: True
# Text length: 31, included: True
# Text length: 19, included: True
# Text length: 5, included: True
# Text length: 11, included: True
# Text length: 40, included: True
# Text length: 28, included: True
# Text length: 13, included: True
# Text length: 22, included: True
# Text length: 21, included: True
# Text length: 41, included: True
# Text length: 31, included: True
# Text length: 3, included: True
# Text length: 15, included: True
# Text length: 6, included: True
# Text length: 27, included: True
# Text length: 8, included: True
# Text length: 25, included: True
# Text length: 22, included: True
# Text length: 17, included: True
# Text length: 6, included: True
# Text length: 16, included: True
# Text length: 10, included: True
# Text length: 4, included: True
# Text length: 11, included: True
# Text length: 7, included: True
# Text length: 5, included: True
# Text length: 15, included: True
# Text length: 7, included: True
# Text length: 23, included: True
# Text length: 3, included: True
# Text length: 17, included: True
# Text length: 25, included: True
# Text length: 10, included: True
# Text length: 34, included: True
# Text length: 16, included: True
# Text length: 8, included: True
# Text length: 40, included: True
# Text length: 38, included: True
# Text length: 22, included: True
# Text length: 13, included: True
# Text length: 37, included: True
# Text length: 41, included: True
# Text length: 24, included: True
# Text length: 44, included: True
# Text length: 10, included: True
# Text length: 7, included: True
# Text length: 63, included: True
# Text length: 7, included: True
# Text length: 16, included: True
# Text length: 46, included: True
# Text length: 39, included: True
# Text length: 93, included: True
# Text length: 5, included: True
# Text length: 42, included: True
# Text length: 4, included: True
# Text length: 26, included: True
# Text length: 6, included: True
# Text length: 12, included: True
# Text length: 63, included: True
# Text length: 66, included: True
# Text length: 10, included: True
# Text length: 27, included: True
# Text length: 67, included: True
# Text length: 35, included: True
# Text length: 24, included: True
# Text length: 71, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 26, included: True
# Text length: 5, included: True
# Text length: 61, included: True
# Text length: 11, included: True
# Text length: 44, included: True
# Text length: 147, included: True
# Text length: 8, included: True
# Text length: 5, included: True
# Text length: 7, included: True
# Text length: 13, included: True
# Text length: 3, included: True
# Text length: 5, included: True
# Text length: 26, included: True
# Text length: 11, included: True
# Text length: 70, included: True
# Text length: 74, included: True
# Text length: 73, included: True
# Text length: 41, included: True
# Text length: 94, included: True
# Text length: 50, included: True
# Text length: 7, included: True
# Text length: 143, included: True
# Text length: 9, included: True
# Text length: 44, included: True
# Text length: 29, included: True
# Text length: 28, included: True
# Text length: 48, included: True
# Text length: 9, included: True
# Text length: 23, included: True
# Text length: 20, included: True
# Text length: 32, included: True
# Text length: 9, included: True
# Text length: 120, included: True
# Text length: 9, included: True
# Text length: 97, included: True
# Text length: 12, included: True
# Text length: 4, included: True
# Text length: 10, included: True
# Text length: 3, included: True
# Text length: 20, included: True
# Text length: 13, included: True
# Text length: 8, included: True
# Text length: 33, included: True
# Text length: 4, included: True
# Text length: 4, included: True
# Text length: 3, included: True
# Text length: 19, included: True
# Text length: 33, included: True
# Text length: 3, included: True
# Text length: 92, included: True
# Text length: 13, included: True
# Text length: 91, included: True
# Text length: 3, included: True
# Text length: 24, included: True
# Text length: 15, included: True
# Text length: 33, included: True
# Text length: 9, included: True
# Text length: 19, included: True
# Text length: 13, included: True
# Text length: 57, included: True
# Text length: 5, included: True
# Text length: 11, included: True
# Text length: 21, included: True
# Text length: 60, included: True
# Text length: 4, included: True
# Text length: 16, included: True
# Text length: 83, included: True
# Text length: 23, included: True
# Text length: 68, included: True
# Text length: 59, included: True
# Text length: 11, included: True
# Text length: 241, included: True
# Text length: 3, included: True
# Text length: 53, included: True
# Text length: 40, included: True
# Text length: 72, included: True
# Text length: 6, included: True
# Text length: 29, included: True
# Text length: 12, included: True
# Text length: 9, included: True
# Text length: 4, included: True
# Text length: 20, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 11, included: True
# Text length: 6, included: True
# Text length: 4, included: True
# Text length: 3, included: True
# Text length: 39, included: True
# Text length: 5, included: True
# Text length: 68, included: True
# Text length: 30, included: True
# Text length: 6, included: True
# Text length: 21, included: True
# Text length: 6, included: True
# Text length: 11, included: True
# Text length: 25, included: True
# Text length: 16, included: True
# Text length: 3, included: True
# Text length: 12, included: True
# Text length: 56, included: True
# Text length: 83, included: True
# Text length: 3, included: True
# Text length: 6, included: True
# Text length: 7, included: True
# Text length: 19, included: True
# Text length: 11, included: True
# Text length: 7, included: True
# Text length: 9, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 41, included: True
# Text length: 9, included: True
# Text length: 6, included: True
# Text length: 15, included: True
# Text length: 28, included: True
# Text length: 42, included: True
# Text length: 15, included: True
# Text length: 35, included: True
# Text length: 6, included: True
# Text length: 16, included: True
# Text length: 22, included: True
# Text length: 64, included: True
# Text length: 39, included: True
# Text length: 53, included: True
# Text length: 90, included: True
# Text length: 39, included: True
# Text length: 40, included: True
# Text length: 16, included: True
# Text length: 113, included: True
# Text length: 13, included: True
# Text length: 72, included: True
# Text length: 20, included: True
# Text length: 26, included: True
# Text length: 4, included: True
# Text length: 3, included: True
# Text length: 24, included: True
# Text length: 36, included: True
# Text length: 25, included: True
# Text length: 37, included: True
# Text length: 20, included: True
# Text length: 22, included: True
# Text length: 33, included: True
# Text length: 34, included: True
# Text length: 20, included: True
# Text length: 17, included: True
# Text length: 4, included: True
# Text length: 6, included: True
# Text length: 21, included: True
# Text length: 3, included: True
# Text length: 119, included: True
# Text length: 73, included: True
# Text length: 4, included: True
# Text length: 6, included: True
# Text length: 3, included: True
# Text length: 9, included: True
# Text length: 3, included: True
# Text length: 14, included: True
# Text length: 26, included: True
# Text length: 104, included: True
# Text length: 14, included: True
# Text length: 26, included: True
# Text length: 32, included: True
# Text length: 26, included: True
# Text length: 5, included: True
# Text length: 3, included: True
# Text length: 31, included: True
# Text length: 6, included: True
# Text length: 12, included: True
# Text length: 34, included: True
# Text length: 7, included: True
# Text length: 12, included: True
# Text length: 31, included: True
# Text length: 20, included: True
# Text length: 11, included: True
# Text length: 19, included: True
# Text length: 3, included: True
# Text length: 4, included: True
# Text length: 24, included: True
# Text length: 4, included: True
# Text length: 4, included: True
# Text length: 11, included: True
# Text length: 29, included: True
# Text length: 24, included: True
# Text length: 14, included: True
# Text length: 9, included: True
# Text length: 3, included: True
# Text length: 15, included: True
# Text length: 3, included: True
# Text length: 47, included: True
# Text length: 11, included: True
# Text length: 7, included: True
# Text length: 80, included: True
# Text length: 19, included: True
# Text length: 38, included: True
# Text length: 14, included: True
# Text length: 13, included: True
# Text length: 12, included: True
# Text length: 14, included: True
# Text length: 4, included: True
# Text length: 25, included: True
# Text length: 6, included: True
# Text length: 10, included: True
# Text length: 4, included: True
# Text length: 18, included: True
# Text length: 34, included: True
# Text length: 44, included: True
# Text length: 54, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 12, included: True
# Text length: 13, included: True
# Text length: 32, included: True
# Text length: 3, included: True
# Text length: 6, included: True
# Text length: 36, included: True
# Text length: 111, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 28, included: True
# Text length: 3, included: True
# Text length: 6, included: True
# Text length: 3, included: True
# Text length: 80, included: True
# Text length: 3, included: True
# Text length: 31, included: True
# Text length: 3, included: True
# Text length: 27, included: True
# Text length: 40, included: True
# Text length: 115, included: True
# Text length: 6, included: True
# Text length: 4, included: True
# Text length: 16, included: True
# Text length: 11, included: True
# Text length: 54, included: True
# Text length: 14, included: True
# Text length: 96, included: True
# Text length: 13, included: True
# Text length: 12, included: True
# Text length: 9, included: True
# Text length: 15, included: True
# Text length: 12, included: True
# Text length: 38, included: True
# Text length: 17, included: True
# Text length: 55, included: True
# Text length: 62, included: True
# Text length: 8, included: True
# Text length: 50, included: True
# Text length: 60, included: True
# Text length: 48, included: True
# Text length: 114, included: True
# Text length: 13, included: True
# Text length: 7, included: True
# Text length: 14, included: True
# Text length: 14, included: True
# Text length: 4, included: True
# Text length: 55, included: True
# Text length: 94, included: True
# Text length: 4, included: True
# Text length: 36, included: True
# Text length: 3, included: True
# Text length: 27, included: True
# Text length: 34, included: True
# Text length: 8, included: True
# Text length: 33, included: True
# Text length: 14, included: True
# Text length: 29, included: True
# Text length: 10, included: True
# Text length: 23, included: True
# Text length: 6, included: True
# Text length: 17, included: True
# Text length: 85, included: True
# Text length: 9, included: True
# Text length: 59, included: True
# Text length: 9, included: True
# Text length: 189, included: True
# Text length: 21, included: True
# Text length: 26, included: True
# Text length: 10, included: True
# Text length: 13, included: True
# Text length: 15, included: True
# Text length: 67, included: True
# Text length: 26, included: True
# Text length: 13, included: True
# Text length: 63, included: True
# Text length: 26, included: True
# Text length: 4, included: True
# Text length: 20, included: True
# Text length: 61, included: True
# Text length: 13, included: True
# Text length: 13, included: True
# Text length: 11, included: True
# Text length: 57, included: True
# Text length: 55, included: True
# Text length: 13, included: True
# Text length: 15, included: True
# Text length: 64, included: True
# Text length: 12, included: True
# Text length: 6, included: True
# Text length: 25, included: True
# Text length: 7, included: True
# Text length: 7, included: True
# Text length: 7, included: True
# Text length: 15, included: True
# Text length: 4, included: True
# Text length: 27, included: True
# Text length: 9, included: True
# Text length: 10, included: True
# Text length: 104, included: True
# Text length: 97, included: True
# Text length: 21, included: True
# Text length: 103, included: True
# Text length: 37, included: True
# Text length: 6, included: True
# Text length: 43, included: True
# Text length: 4, included: True
# Text length: 26, included: True
# Text length: 22, included: True
# Text length: 6, included: True
# Text length: 13, included: True
# Text length: 24, included: True
# Text length: 32, included: True
# Text length: 23, included: True
# Text length: 14, included: True
# Text length: 13, included: True
# Text length: 39, included: True
# Text length: 17, included: True
# Text length: 48, included: True
# Text length: 14, included: True
# Text length: 30, included: True
# Text length: 5, included: True
# Text length: 27, included: True
# Text length: 31, included: True
# Text length: 43, included: True
# Text length: 17, included: True
# Text length: 59, included: True
# Text length: 31, included: True
# Text length: 10, included: True
# Text length: 103, included: True
# Text length: 12, included: True
# Text length: 7, included: True
# Text length: 13, included: True
# Text length: 23, included: True
# Text length: 80, included: True
# Text length: 22, included: True
# Text length: 21, included: True
# Text length: 33, included: True
# Text length: 19, included: True
# Text length: 6, included: True
# Text length: 42, included: True
# Text length: 4, included: True
# Text length: 10, included: True
# Text length: 20, included: True
# Text length: 3, included: True
# Text length: 23, included: True
# Text length: 42, included: True
# Text length: 38, included: True
# Text length: 34, included: True
# Text length: 34, included: True
# Text length: 96, included: True
# Text length: 19, included: True
# Text length: 16, included: True
# Text length: 6, included: True
# Text length: 12, included: True
# Text length: 22, included: True
# Text length: 12, included: True
# Text length: 27, included: True
# Text length: 4, included: True
# Text length: 14, included: True
# Text length: 33, included: True
# Text length: 47, included: True
# Text length: 4, included: True
# Text length: 51, included: True
# Text length: 161, included: True
# Text length: 4, included: True
# Text length: 10, included: True
# Text length: 30, included: True
# Text length: 8, included: True
# Text length: 16, included: True
# Text length: 48, included: True
# Text length: 17, included: True
# Text length: 48, included: True
# Text length: 4, included: True
# Text length: 59, included: True
# Text length: 3, included: True
# Text length: 35, included: True
# Text length: 20, included: True
# Text length: 62, included: True
# Text length: 13, included: True
# Text length: 51, included: True
# Text length: 13, included: True
# Text length: 48, included: True
# Text length: 23, included: True
# Text length: 79, included: True
# Text length: 39, included: True
# Text length: 85, included: True
# Text length: 8, included: True
# Text length: 17, included: True
# Text length: 10, included: True
# Text length: 18, included: True
# Text length: 3, included: True
# Text length: 50, included: True
# Text length: 26, included: True
# Text length: 36, included: True
# Text length: 48, included: True
# Text length: 29, included: True
# Text length: 9, included: True
# Text length: 50, included: True
# Text length: 5, included: True
# Text length: 28, included: True
# Text length: 29, included: True
# Text length: 6, included: True
# Text length: 13, included: True
# Text length: 12, included: True
# Text length: 24, included: True
# Text length: 102, included: True
# Text length: 91, included: True
# Text length: 82, included: True
# Text length: 18, included: True
# Text length: 18, included: True
# Text length: 8, included: True
# Text length: 109, included: True
# Text length: 11, included: True
# Text length: 24, included: True
# Text length: 4, included: True
# Text length: 34, included: True
# Text length: 35, included: True
# Text length: 3, included: True
# Text length: 37, included: True
# Text length: 49, included: True
# Text length: 4, included: True
# Text length: 3, included: True
# Text length: 5, included: True
# Text length: 17, included: True
# Text length: 12, included: True
# Text length: 3, included: True
# Text length: 48, included: True
# Text length: 91, included: True
# Text length: 26, included: True
# Text length: 4, included: True
# Text length: 9, included: True
# Text length: 8, included: True
# Text length: 3, included: True
# Text length: 12, included: True
# Text length: 3, included: True
# Text length: 25, included: True
# Text length: 11, included: True
# Text length: 13, included: True
# Text length: 48, included: True
# Text length: 33, included: True
# Text length: 3, included: True
# Text length: 26, included: True
# Text length: 29, included: True
# Text length: 3, included: True
# Text length: 20, included: True
# Text length: 48, included: True
# Text length: 13, included: True
# Text length: 33, included: True
# Text length: 12, included: True
# Text length: 22, included: True
# Text length: 13, included: True
# Text length: 29, included: True
# Text length: 32, included: True
# Text length: 13, included: True
# Text length: 3, included: True
# Text length: 31, included: True
# Text length: 32, included: True
# Text length: 104, included: True
# Text length: 3, included: True
# Text length: 17, included: True
# Text length: 12, included: True
# Text length: 36, included: True
# Text length: 19, included: True
# Text length: 3, included: True
# Text length: 13, included: True
# Text length: 3, included: True
# Text length: 17, included: True
# Text length: 38, included: True
# Text length: 42, included: True
# Text length: 12, included: True
# Text length: 108, included: True
# Text length: 27, included: True
# Text length: 230, included: True
# Text length: 106, included: True
# Text length: 7, included: True
# Text length: 44, included: True
# Text length: 10, included: True
# Text length: 13, included: True
# Text length: 16, included: True
# Text length: 214, included: True
# Text length: 24, included: True
# Text length: 26, included: True
# Text length: 20, included: True
# Text length: 3, included: True
# Text length: 5, included: True
# Text length: 13, included: True
# Text length: 19, included: True
# Text length: 100, included: True
# Text length: 23, included: True
# Text length: 77, included: True
# Text length: 31, included: True
# Text length: 12, included: True
# Text length: 25, included: True
# Text length: 25, included: True
# Text length: 11, included: True
# Text length: 18, included: True
# Text length: 66, included: True
# Text length: 14, included: True
# Text length: 3, included: True
# Text length: 114, included: True
# Text length: 70, included: True
# Text length: 4, included: True
# Text length: 26, included: True
# Text length: 152, included: True
# Text length: 7, included: True
# Text length: 10, included: True
# Text length: 7, included: True
# Text length: 17, included: True
# Text length: 79, included: True
# Text length: 13, included: True
# Text length: 82, included: True
# Text length: 3, included: True
# Text length: 4, included: True
# Text length: 91, included: True
# Text length: 7, included: True
# Text length: 22, included: True
# Text length: 58, included: True
# Text length: 10, included: True
# Text length: 13, included: True
# Text length: 3, included: True
# Text length: 9, included: True
# Text length: 57, included: True
# Text length: 36, included: True
# Text length: 44, included: True
# Text length: 3, included: True
# Text length: 102, included: True
# Text length: 35, included: True
# Text length: 25, included: True
# Text length: 4, included: True
# Text length: 96, included: True
# Text length: 36, included: True
# Text length: 20, included: True
# Text length: 4, included: True
# Text length: 28, included: True
# Text length: 3, included: True
# Text length: 12, included: True
# Text length: 12, included: True
# Text length: 12, included: True
# Text length: 64, included: True
# Text length: 37, included: True
# Text length: 74, included: True
# Text length: 22, included: True
# Text length: 66, included: True
# Text length: 233, included: True
# Text length: 7, included: True
# Text length: 49, included: True
# Text length: 25, included: True
# Text length: 67, included: True
# Text length: 17, included: True
# Text length: 139, included: True
# Text length: 24, included: True
# Text length: 32, included: True
# Text length: 96, included: True
# Text length: 57, included: True
# Text length: 135, included: True
# Text length: 25, included: True
# Text length: 49, included: True
# Text length: 28, included: True
# Text length: 25, included: True
# Text length: 96, included: True
# Text length: 73, included: True
# Text length: 59, included: True
# Text length: 8, included: True
# Text length: 24, included: True
# Text length: 19, included: True
# Text length: 9, included: True
# Text length: 16, included: True
# Text length: 5, included: True
# Text length: 5, included: True
# Text length: 54, included: True
# Text length: 29, included: True
# Text length: 4, included: True
# Text length: 6, included: True
# Text length: 4, included: True
# Text length: 27, included: True
# Text length: 11, included: True
# Text length: 118, included: True
# Text length: 3, included: True
# Text length: 62, included: True
# Text length: 84, included: True
# Text length: 3, included: True
# Text length: 12, included: True
# Text length: 122, included: True
# Text length: 30, included: True
# Text length: 53, included: True
# Text length: 13, included: True
# Text length: 7, included: True
# Text length: 57, included: True
# Text length: 57, included: True
# Text length: 64, included: True
# Text length: 22, included: True
# Text length: 24, included: True
# Text length: 26, included: True
# Text length: 4, included: True
# Text length: 13, included: True
# Text length: 58, included: True
# Text length: 68, included: True
# Text length: 70, included: True
# Text length: 209, included: True
# Text length: 27, included: True
# Text length: 38, included: True
# Text length: 5, included: True
# Text length: 4, included: True
# Text length: 10, included: True
# Text length: 35, included: True
# Text length: 10, included: True
# Text length: 14, included: True
# Text length: 68, included: True
# Text length: 14, included: True
# Text length: 52, included: True
# Text length: 69, included: True
# Text length: 34, included: True
# Text length: 26, included: True
# Text length: 115, included: True
# Text length: 52, included: True
# Text length: 70, included: True
# Text length: 49, included: True
# Text length: 29, included: True
# Text length: 13, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 26, included: True
# Text length: 15, included: True
# Text length: 39, included: True
# Text length: 5, included: True
# Text length: 11, included: True
# Text length: 18, included: True
# Text length: 37, included: True
# Text length: 13, included: True
# Text length: 7, included: True
# Text length: 5, included: True
# Text length: 3, included: True
# Text length: 43, included: True
# Text length: 86, included: True
# Text length: 3, included: True
# Text length: 31, included: True
# Text length: 28, included: True
# Text length: 4, included: True
# Text length: 15, included: True
# Text length: 5, included: True
# Text length: 52, included: True
# Text length: 7, included: True
# Text length: 5, included: True
# Text length: 20, included: True
# Text length: 3, included: True
# Text length: 4, included: True
# Text length: 11, included: True
# Text length: 46, included: True
# Text length: 166, included: True
# Text length: 68, included: True
# Text length: 13, included: True
# Text length: 64, included: True
# Text length: 16, included: True
# Text length: 11, included: True
# Text length: 7, included: True
# Text length: 9, included: True
# Text length: 12, included: True
# Text length: 7, included: True
# Text length: 8, included: True
# Text length: 8, included: True
# Text length: 17, included: True
# Text length: 64, included: True
# Text length: 8, included: True
# Text length: 31, included: True
# Text length: 8, included: True
# Text length: 8, included: True
# Text length: 38, included: True
# Text length: 90, included: True
# Text length: 30, included: True
# Text length: 12, included: True
# Text length: 29, included: True
# Text length: 25, included: True
# Text length: 27, included: True
# Text length: 41, included: True
# Text length: 19, included: True
# Text length: 10, included: True
# Text length: 28, included: True
# Text length: 47, included: True
# Text length: 13, included: True
# Text length: 47, included: True
# Text length: 18, included: True
# Text length: 19, included: True
# Text length: 49, included: True
# Text length: 78, included: True
# Text length: 25, included: True
# Text length: 36, included: True
# Text length: 6, included: True
# Text length: 69, included: True
# Text length: 36, included: True
# Text length: 19, included: True
# Text length: 13, included: True
# Text length: 17, included: True
# Text length: 24, included: True
# Text length: 48, included: True
# Text length: 20, included: True
# Text length: 47, included: True
# Text length: 21, included: True
# Text length: 50, included: True
# Text length: 28, included: True
# Text length: 98, included: True
# Text length: 93, included: True
# Text length: 47, included: True
# Text length: 83, included: True
# Text length: 51, included: True
# Text length: 5, included: True
# Text length: 23, included: True
# Text length: 9, included: True
# Text length: 127, included: True
# Text length: 27, included: True
# Text length: 18, included: True
# Text length: 23, included: True
# Text length: 8, included: True
# Text length: 13, included: True
# Text length: 16, included: True
# Text length: 111, included: True
# Text length: 16, included: True
# Text length: 11, included: True
# Text length: 48, included: True
# Text length: 72, included: True
# Text length: 3, included: True
# Text length: 7, included: True
# Text length: 34, included: True
# Text length: 4, included: True
# Text length: 24, included: True
# Text length: 27, included: True
# Text length: 14, included: True
# Text length: 52, included: True
# Text length: 20, included: True
# Text length: 18, included: True
# Text length: 12, included: True
# Text length: 27, included: True
# Text length: 8, included: True
# Text length: 7, included: True
# Text length: 26, included: True
# Text length: 18, included: True
# Text length: 11, included: True
# Text length: 9, included: True
# Text length: 8, included: True
# Text length: 23, included: True
# Text length: 46, included: True
# Text length: 12, included: True
# Text length: 13, included: True
# Text length: 56, included: True
# Text length: 30, included: True
# Text length: 53, included: True
# Text length: 7, included: True
# Text length: 73, included: True
# Text length: 58, included: True
# Text length: 8, included: True
# Text length: 13, included: True
# Text length: 11, included: True
# Text length: 60, included: True
# Text length: 45, included: True
# Text length: 14, included: True
# Text length: 30, included: True
# Text length: 27, included: True
# Text length: 6, included: True
# Text length: 55, included: True
# Text length: 32, included: True
# Text length: 16, included: True
# Text length: 13, included: True
# Text length: 10, included: True
# Text length: 13, included: True
# Text length: 58, included: True
# Text length: 13, included: True
# Text length: 25, included: True
# Text length: 10, included: True
# Text length: 6, included: True
# Text length: 20, included: True
# Text length: 7, included: True
# Text length: 59, included: True
# Text length: 56, included: True
# Text length: 8, included: True
# Text length: 18, included: True
# Text length: 32, included: True
# Text length: 4, included: True
# Text length: 23, included: True
# Text length: 59, included: True
# Text length: 44, included: True
# Text length: 97, included: True
# Text length: 9, included: True
# Text length: 23, included: True
# Text length: 37, included: True
# Text length: 35, included: True
# Text length: 15, included: True
# Text length: 3, included: True
# Text length: 58, included: True
# Text length: 58, included: True
# Text length: 4, included: True
# Text length: 11, included: True
# Text length: 26, included: True
# Text length: 36, included: True
# Text length: 13, included: True
# Text length: 35, included: True
# Text length: 8, included: True
# Text length: 12, included: True
# Text length: 26, included: True
# Text length: 32, included: True
# Text length: 12, included: True
# Text length: 116, included: True
# Text length: 29, included: True
# Text length: 3, included: True
# Text length: 33, included: True
# Text length: 27, included: True
# Text length: 13, included: True
# Text length: 61, included: True
# Text length: 20, included: True
# Text length: 38, included: True
# Text length: 3, included: True
# Text length: 26, included: True
# Text length: 85, included: True
# Text length: 37, included: True
# Text length: 70, included: True
# Text length: 54, included: True
# Text length: 57, included: True
# Text length: 62, included: True
# Text length: 38, included: True
# Text length: 33, included: True
# Text length: 71, included: True
# Text length: 31, included: True
# Text length: 22, included: True
# Text length: 122, included: True
# Text length: 19, included: True
# Text length: 26, included: True
# Text length: 48, included: True
# Text length: 22, included: True
# Text length: 119, included: True
# Text length: 24, included: True
# Text length: 5, included: True
# Text length: 15, included: True
# Text length: 33, included: True
# Text length: 25, included: True
# Text length: 3, included: True
# Text length: 33, included: True
# Text length: 10, included: True
# Text length: 43, included: True
# Text length: 37, included: True
# Text length: 8, included: True
# Text length: 24, included: True
# Text length: 21, included: True
# Text length: 26, included: True
# Text length: 70, included: True
# Text length: 8, included: True
# Text length: 101, included: True
# Text length: 24, included: True
# Text length: 16, included: True
# Text length: 34, included: True
# Text length: 54, included: True
# Text length: 88, included: True
# Text length: 23, included: True
# Text length: 11, included: True
# Text length: 31, included: True
# Text length: 8, included: True
# Text length: 3, included: True
# Text length: 4, included: True
# Text length: 39, included: True
# Text length: 33, included: True
# Text length: 9, included: True
# Text length: 11, included: True
# Text length: 27, included: True
# Text length: 3, included: True
# Text length: 4, included: True
# Text length: 56, included: True
# Text length: 35, included: True
# Text length: 5, included: True
# Text length: 10, included: True
# Text length: 35, included: True
# Text length: 5, included: True
# Text length: 25, included: True
# Text length: 55, included: True
# Text length: 59, included: True
# Text length: 8, included: True
# Text length: 42, included: True
# Text length: 109, included: True
# Text length: 39, included: True
# Text length: 98, included: True
# Text length: 71, included: True
# Text length: 158, included: True
# Text length: 6, included: True
# Text length: 81, included: True
# Text length: 79, included: True
# Text length: 4, included: True
# Text length: 3, included: True
# Text length: 52, included: True
# Text length: 76, included: True
# Text length: 98, included: True
# Text length: 129, included: True
# Text length: 271, included: True
# Text length: 61, included: True
# Text length: 6, included: True
# Text length: 108, included: True
# Text length: 4, included: True
# Text length: 28, included: True
# Text length: 7, included: True
# Text length: 5, included: True
# Text length: 14, included: True
# Text length: 19, included: True
# Text length: 33, included: True
# Text length: 32, included: True
# Text length: 9, included: True
# Text length: 62, included: True
# Text length: 17, included: True
# Text length: 12, included: True
# Text length: 64, included: True
# Text length: 17, included: True
# Text length: 10, included: True
# Text length: 7, included: True
# Text length: 40, included: True
# Text length: 66, included: True
# Text length: 21, included: True
# Text length: 30, included: True
# Text length: 15, included: True
# Text length: 53, included: True
# Text length: 106, included: True
# Text length: 31, included: True
# Text length: 13, included: True
# Text length: 74, included: True
# Text length: 17, included: True
# Text length: 12, included: True
# Text length: 4, included: True
# Text length: 14, included: True
# Text length: 96, included: True
# Text length: 50, included: True
# Text length: 44, included: True
# Text length: 49, included: True
# Text length: 27, included: True
# Text length: 10, included: True
# Text length: 54, included: True
# Text length: 77, included: True
# Text length: 12, included: True
# Text length: 8, included: True
# Text length: 11, included: True
# Text length: 28, included: True
# Text length: 4, included: True
# Text length: 12, included: True
# Text length: 4, included: True
# Text length: 25, included: True
# Text length: 10, included: True
# Text length: 11, included: True
# Text length: 54, included: True
# Text length: 13, included: True
# Text length: 4, included: True
# Text length: 5, included: True
# Text length: 31, included: True
# Text length: 83, included: True
# Text length: 3, included: True
# Text length: 6, included: True
# Text length: 17, included: True
# Text length: 11, included: True
# Text length: 32, included: True
# Text length: 72, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 31, included: True
# Text length: 11, included: True
# Text length: 23, included: True
# Text length: 3, included: True
# Text length: 4, included: True
# Text length: 37, included: True
# Text length: 3, included: True
# Text length: 8, included: True
# Text length: 5, included: True
# Text length: 85, included: True
# Text length: 55, included: True
# Text length: 265, included: True
# Text length: 30, included: True
# Text length: 23, included: True
# Text length: 19, included: True
# Text length: 27, included: True
# Text length: 7, included: True
# Text length: 18, included: True
# Text length: 167, included: True
# Text length: 33, included: True
# Text length: 19, included: True
# Text length: 137, included: True
# Text length: 108, included: True
# Text length: 6, included: True
# Text length: 5, included: True
# Text length: 37, included: True
# Text length: 31, included: True
# Text length: 25, included: True
# Text length: 124, included: True
# Text length: 117, included: True
# Text length: 160, included: True
# Text length: 18, included: True
# Text length: 19, included: True
# Text length: 9, included: True
# Text length: 24, included: True
# Text length: 55, included: True
# Text length: 52, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 42, included: True
# Text length: 72, included: True
# Text length: 18, included: True
# Text length: 3, included: True
# Text length: 42, included: True
# Text length: 12, included: True
# Text length: 44, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 13, included: True
# Text length: 23, included: True
# Text length: 57, included: True
# Text length: 4, included: True
# Text length: 8, included: True
# Text length: 50, included: True
# Text length: 32, included: True
# Text length: 41, included: True
# Text length: 18, included: True
# Text length: 7, included: True
# Text length: 127, included: True
# Text length: 63, included: True
# Text length: 31, included: True
# Text length: 3, included: True
# Text length: 211, included: True
# Text length: 10, included: True
# Text length: 6, included: True
# Text length: 4, included: True
# Text length: 15, included: True
# Text length: 38, included: True
# Text length: 10, included: True
# Text length: 41, included: True
# Text length: 5, included: True
# Text length: 21, included: True
# Text length: 6, included: True
# Text length: 36, included: True
# Text length: 159, included: True
# Text length: 113, included: True
# Text length: 18, included: True
# Text length: 21, included: True
# Text length: 103, included: True
# Text length: 45, included: True
# Text length: 5, included: True
# Text length: 28, included: True
# Text length: 14, included: True
# Text length: 24, included: True
# Text length: 23, included: True
# Text length: 56, included: True
# Text length: 197, included: True
# Text length: 15, included: True
# Text length: 68, included: True
# Text length: 9, included: True
# Text length: 21, included: True
# Text length: 31, included: True
# Text length: 73, included: True
# Text length: 12, included: True
# Text length: 79, included: True
# Text length: 69, included: True
# Text length: 87, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 22, included: True
# Text length: 66, included: True
# Text length: 12, included: True
# Text length: 4, included: True
# Text length: 11, included: True
# Text length: 27, included: True
# Text length: 4, included: True
# Text length: 8, included: True
# Text length: 273, included: True
# Text length: 13, included: True
# Text length: 40, included: True
# Text length: 76, included: True
# Text length: 39, included: True
# Text length: 30, included: True
# Text length: 27, included: True
# Text length: 11, included: True
# Text length: 14, included: True
# Text length: 19, included: True
# Text length: 27, included: True
# Text length: 4, included: True
# Text length: 66, included: True
# Text length: 38, included: True
# Text length: 16, included: True
# Text length: 48, included: True
# Text length: 28, included: True
# Text length: 13, included: True
# Text length: 55, included: True
# Text length: 59, included: True
# Text length: 23, included: True
# Text length: 3, included: True
# Text length: 7, included: True
# Text length: 12, included: True
# Text length: 19, included: True
# Text length: 30, included: True
# Text length: 17, included: True
# Text length: 19, included: True
# Text length: 12, included: True
# Text length: 35, included: True
# Text length: 19, included: True
# Text length: 7, included: True
# Text length: 26, included: True
# Text length: 3, included: True
# Text length: 40, included: True
# Text length: 157, included: True
# Text length: 25, included: True
# Text length: 16, included: True
# Text length: 8, included: True
# Text length: 6, included: True
# Text length: 19, included: True
# Text length: 14, included: True
# Text length: 12, included: True
# Text length: 3, included: True
# Text length: 8, included: True
# Text length: 16, included: True
# Text length: 8, included: True
# Text length: 11, included: True
# Text length: 19, included: True
# Text length: 9, included: True
# Text length: 9, included: True
# Text length: 29, included: True
# Text length: 37, included: True
# Text length: 5, included: True
# Text length: 3, included: True
# Text length: 4, included: True
# Text length: 3, included: True
# Text length: 27, included: True
# Text length: 18, included: True
# Text length: 33, included: True
# Text length: 97, included: True
# Text length: 13, included: True
# Text length: 24, included: True
# Text length: 52, included: True
# Text length: 11, included: True
# Text length: 12, included: True
# Text length: 5, included: True
# Text length: 16, included: True
# Text length: 281, included: True
# Text length: 13, included: True
# Text length: 10, included: True
# Text length: 4, included: True
# Text length: 33, included: True
# Text length: 38, included: True
# Text length: 13, included: True
# Text length: 143, included: True
# Text length: 7, included: True
# Text length: 166, included: True
# Text length: 3, included: True
# Text length: 12, included: True
# Text length: 9, included: True
# Text length: 19, included: True
# Text length: 33, included: True
# Text length: 32, included: True
# Text length: 120, included: True
# Text length: 30, included: True
# Text length: 4, included: True
# Text length: 3, included: True
# Text length: 9, included: True
# Text length: 3, included: True
# Text length: 20, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 10, included: True
# Text length: 52, included: True
# Text length: 51, included: True
# Text length: 19, included: True
# Text length: 16, included: True
# Text length: 14, included: True
# Text length: 23, included: True
# Text length: 8, included: True
# Text length: 11, included: True
# Text length: 37, included: True
# Text length: 17, included: True
# Text length: 13, included: True
# Text length: 10, included: True
# Text length: 39, included: True
# Text length: 33, included: True
# Text length: 36, included: True
# Text length: 213, included: True
# Text length: 4, included: True
# Text length: 6, included: True
# Text length: 12, included: True
# Text length: 6, included: True
# Text length: 7, included: True
# Text length: 92, included: True
# Text length: 11, included: True
# Text length: 4, included: True
# Text length: 14, included: True
# Text length: 136, included: True
# Text length: 31, included: True
# Text length: 137, included: True
# Text length: 13, included: True
# Text length: 23, included: True
# Text length: 53, included: True
# Text length: 3, included: True
# Text length: 16, included: True
# Text length: 16, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 34, included: True
# Text length: 40, included: True
# Text length: 35, included: True
# Text length: 37, included: True
# Text length: 53, included: True
# Text length: 96, included: True
# Text length: 37, included: True
# Text length: 25, included: True
# Text length: 34, included: True
# Text length: 211, included: True
# Text length: 22, included: True
# Text length: 3, included: True
# Text length: 74, included: True
# Text length: 84, included: True
# Text length: 51, included: True
# Text length: 6, included: True
# Text length: 3, included: True
# Text length: 11, included: True
# Text length: 3, included: True
# Text length: 159, included: True
# Text length: 119, included: True
# Text length: 71, included: True
# Text length: 50, included: True
# Text length: 41, included: True
# Text length: 25, included: True
# Text length: 11, included: True
# Text length: 9, included: True
# Text length: 15, included: True
# Text length: 37, included: True
# Text length: 16, included: True
# Text length: 47, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 54, included: True
# Text length: 33, included: True
# Text length: 6, included: True
# Text length: 71, included: True
# Text length: 31, included: True
# Text length: 13, included: True
# Text length: 3, included: True
# Text length: 89, included: True
# Text length: 58, included: True
# Text length: 9, included: True
# Text length: 219, included: True
# Text length: 16, included: True
# Text length: 61, included: True
# Text length: 15, included: True
# Text length: 3, included: True
# Text length: 4, included: True
# Text length: 9, included: True
# Text length: 6, included: True
# Text length: 5, included: True
# Text length: 263, included: True
# Text length: 28, included: True
# Text length: 19, included: True
# Text length: 100, included: True
# Text length: 28, included: True
# Text length: 20, included: True
# Text length: 71, included: True
# Text length: 28, included: True
# Text length: 58, included: True
# Text length: 21, included: True
# Text length: 13, included: True
# Text length: 70, included: True
# Text length: 38, included: True
# Text length: 4, included: True
# Text length: 93, included: True
# Text length: 16, included: True
# Text length: 11, included: True
# Text length: 11, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 13, included: True
# Text length: 5, included: True
# Text length: 13, included: True
# Text length: 4, included: True
# Text length: 12, included: True
# Text length: 39, included: True
# Text length: 42, included: True
# Text length: 36, included: True
# Text length: 34, included: True
# Text length: 14, included: True
# Text length: 10, included: True
# Text length: 7, included: True
# Text length: 3, included: True
# Text length: 12, included: True
# Text length: 32, included: True
# Text length: 27, included: True
# Text length: 52, included: True
# Text length: 56, included: True
# Text length: 56, included: True
# Text length: 43, included: True
# Text length: 5, included: True
# Text length: 50, included: True
# Text length: 64, included: True
# Text length: 3, included: True
# Text length: 4, included: True
# Text length: 15, included: True
# Text length: 41, included: True
# Text length: 5, included: True
# Text length: 4, included: True
# Text length: 12, included: True
# Text length: 3, included: True
# Text length: 29, included: True
# Text length: 11, included: True
# Text length: 20, included: True
# Text length: 3, included: True
# Text length: 26, included: True
# Text length: 10, included: True
# Text length: 32, included: True
# Text length: 18, included: True
# Text length: 137, included: True
# Text length: 168, included: True
# Text length: 10, included: True
# Text length: 6, included: True
# Text length: 32, included: True
# Text length: 29, included: True
# Text length: 6, included: True
# Text length: 105, included: True
# Text length: 4, included: True
# Text length: 15, included: True
# Text length: 3, included: True
# Text length: 4, included: True
# Text length: 8, included: True
# Text length: 135, included: True
# Text length: 24, included: True
# Text length: 4, included: True
# Text length: 22, included: True
# Text length: 10, included: True
# Text length: 39, included: True
# Text length: 10, included: True
# Text length: 3, included: True
# Text length: 7, included: True
# Text length: 6, included: True
# Text length: 11, included: True
# Text length: 343, included: True
# Text length: 22, included: True
# Text length: 82, included: True
# Text length: 13, included: True
# Text length: 29, included: True
# Text length: 37, included: True
# Text length: 22, included: True
# Text length: 7, included: True
# Text length: 15, included: True
# Text length: 7, included: True
# Text length: 29, included: True
# Text length: 10, included: True
# Text length: 8, included: True
# Text length: 12, included: True
# Text length: 8, included: True
# Text length: 18, included: True
# Text length: 23, included: True
# Text length: 25, included: True
# Text length: 8, included: True
# Text length: 20, included: True
# Text length: 18, included: True
# Text length: 12, included: True
# Text length: 23, included: True
# Text length: 24, included: True
# Text length: 54, included: True
# Text length: 67, included: True
# Text length: 39, included: True
# Text length: 7, included: True
# Text length: 18, included: True
# Text length: 33, included: True
# Text length: 23, included: True
# Text length: 28, included: True
# Text length: 11, included: True
# Text length: 27, included: True
# Text length: 26, included: True
# Text length: 12, included: True
# Text length: 22, included: True
# Text length: 8, included: True
# Text length: 8, included: True
# Text length: 8, included: True
# Text length: 20, included: True
# Text length: 5, included: True
# Text length: 47, included: True
# Text length: 7, included: True
# Text length: 32, included: True
# Text length: 148, included: True
# Text length: 8, included: True
# Text length: 5, included: True
# Text length: 14, included: True
# Text length: 46, included: True
# Text length: 5, included: True
# Text length: 27, included: True
# Text length: 55, included: True
# Text length: 13, included: True
# Text length: 271, included: True
# Text length: 13, included: True
# Text length: 28, included: True
# Text length: 14, included: True
# Text length: 39, included: True
# Text length: 19, included: True
# Text length: 40, included: True
# Text length: 7, included: True
# Text length: 3, included: True
# Text length: 30, included: True
# Text length: 4, included: True
# Text length: 27, included: True
# Text length: 13, included: True
# Text length: 3, included: True
# Text length: 14, included: True
# Text length: 54, included: True
# Text length: 21, included: True
# Text length: 13, included: True
# Text length: 4, included: True
# Text length: 68, included: True
# Text length: 78, included: True
# Text length: 36, included: True
# Text length: 19, included: True
# Text length: 102, included: True
# Text length: 13, included: True
# Text length: 11, included: True
# Text length: 16, included: True
# Text length: 44, included: True
# Text length: 3, included: True
# Text length: 23, included: True
# Text length: 13, included: True
# Text length: 21, included: True
# Text length: 9, included: True
# Text length: 231, included: True
# Text length: 38, included: True
# Text length: 18, included: True
# Text length: 44, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 9, included: True
# Text length: 72, included: True
# Text length: 13, included: True
# Text length: 82, included: True
# Text length: 43, included: True
# Text length: 56, included: True
# Text length: 86, included: True
# Text length: 13, included: True
# Text length: 92, included: True
# Text length: 21, included: True
# Text length: 28, included: True
# Text length: 30, included: True
# Text length: 4, included: True
# Text length: 25, included: True
# Text length: 23, included: True
# Text length: 21, included: True
# Text length: 3, included: True
# Text length: 46, included: True
# Text length: 4, included: True
# Text length: 11, included: True
# Text length: 12, included: True
# Text length: 4, included: True
# Text length: 9, included: True
# Text length: 76, included: True
# Text length: 34, included: True
# Text length: 129, included: True
# Text length: 8, included: True
# Text length: 60, included: True
# Text length: 105, included: True
# Text length: 4, included: True
# Text length: 4, included: True
# Text length: 5, included: True
# Text length: 45, included: True
# Text length: 105, included: True
# Text length: 13, included: True
# Text length: 47, included: True
# Text length: 124, included: True
# Text length: 25, included: True
# Text length: 24, included: True
# Text length: 22, included: True
# Text length: 27, included: True
# Text length: 14, included: True
# Text length: 41, included: True
# Text length: 13, included: True
# Text length: 5, included: True
# Text length: 31, included: True
# Text length: 22, included: True
# Text length: 13, included: True
# Text length: 65, included: True
# Text length: 3, included: True
# Text length: 9, included: True
# Text length: 17, included: True
# Text length: 7, included: True
# Text length: 4, included: True
# Text length: 3, included: True
# Text length: 25, included: True
# Text length: 11, included: True
# Text length: 13, included: True
# Text length: 18, included: True
# Text length: 195, included: True
# Text length: 9, included: True
# Text length: 48, included: True
# Text length: 46, included: True
# Text length: 19, included: True
# Text length: 46, included: True
# Text length: 11, included: True
# Text length: 10, included: True
# Text length: 10, included: True
# Text length: 41, included: True
# Text length: 34, included: True
# Text length: 22, included: True
# Text length: 34, included: True
# Text length: 35, included: True
# Text length: 13, included: True
# Text length: 7, included: True
# Text length: 25, included: True
# Text length: 89, included: True
# Text length: 102, included: True
# Text length: 62, included: True
# Text length: 39, included: True
# Text length: 26, included: True
# Text length: 16, included: True
# Text length: 22, included: True
# Text length: 16, included: True
# Text length: 32, included: True
# Text length: 31, included: True
# Text length: 27, included: True
# Text length: 44, included: True
# Text length: 219, included: True
# Text length: 107, included: True
# Text length: 3, included: True
# Text length: 58, included: True
# Text length: 21, included: True
# Text length: 159, included: True
# Text length: 17, included: True
# Text length: 31, included: True
# Text length: 3, included: True
# Text length: 32, included: True
# Text length: 93, included: True
# Text length: 69, included: True
# Text length: 4, included: True
# Text length: 3, included: True
# Text length: 19, included: True
# Text length: 26, included: True
# Text length: 13, included: True
# Text length: 3, included: True
# Text length: 9, included: True
# Text length: 18, included: True
# Text length: 17, included: True
# Text length: 23, included: True
# Text length: 23, included: True
# Text length: 27, included: True
# Text length: 89, included: True
# Text length: 16, included: True
# Text length: 55, included: True
# Text length: 22, included: True
# Text length: 5, included: True
# Text length: 4, included: True
# Text length: 57, included: True
# Text length: 6, included: True
# Text length: 4, included: True
# Text length: 72, included: True
# Text length: 85, included: True
# Text length: 18, included: True
# Text length: 47, included: True
# Text length: 3, included: True
# Text length: 3, included: True
# Text length: 63, included: True
# Text length: 126, included: True
# Text length: 42, included: True
# Text length: 17, included: True
# Text length: 82, included: True
# Text length: 105, included: True
# Text length: 110, included: True
# Text length: 44, included: True
# Text length: 25, included: True
# Text length: 39, included: True
# Text length: 30, included: True
# Text length: 61, included: True
# Text length: 23, included: True
# Text length: 19, included: True
# Text length: 29, included: True
# Text length: 282, included: True
# Text length: 22, included: True
# Text length: 15, included: True
# Text length: 31, included: True
# Text length: 13, included: True
# Text length: 13, included: True
# Text length: 3, included: True
# Text length: 13, included: True
# Text length: 3, included: True
# Text length: 12, included: True
# Text length: 12, included: True
# Text length: 15, included: True
# Text length: 30, included: True
# Text length: 194, included: True
# Text length: 11, included: True

# %%
import pandas as pd
from transformers import pipeline

# Read the filtered CSV file
filtered_df = pd.read_csv('filtered_message.csv')

# Extract data from "Content" column
filtered_content_data = filtered_df['Content'].tolist()

# Define the sentiment analysis model to use
model_name = "cardiffnlp/twitter-roberta-base-sentiment-latest"

try:
    # Load the sentiment analysis pipeline
    sentiment_pipeline = pipeline("sentiment-analysis", model=model_name)

    # Perform sentiment analysis
    results = sentiment_pipeline(filtered_content_data)

    # Extract labels and scores
    labels = [result['label'] for result in results]
    scores = [result['score'] for result in results]

    # Add results to the dataframe
    filtered_df['Label'] = labels
    filtered_df['Score'] = scores

    # Save results to a new CSV file
    filtered_df.to_csv('message_with_sentiment.csv', index=False)

    # Output to verify
    print(filtered_df.head())
except Exception as e:
    print(f"An error occurred with model {model_name}: {e}")
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#        AuthorID              Author                 Date  \
# 0  1.460000e+17           chartguy.  01/01/2024 05:56 AM
# 1  1.030000e+18  toxicwaifu.dcl.eth  01/01/2024 08:01 AM
# 2  8.740000e+17        cheddarqueso  01/01/2024 08:23 AM
# 3  8.580000e+17      help_center017  01/01/2024 12:11 PM
# 4  8.580000e+17      help_center017  01/01/2024 12:11 PM
#
#                                              Content Attachments  \
# 0                                                 Hi         NaN
# 1                Happy New Year from Germany â¨ð         NaN
# 2  Happy New Year DCL fam and team. I am thankful...         NaN
# 3                                            Welcome         NaN
# 4                                Happy new year ð         NaN
#
#              Reactions     Label     Score
# 0                  NaN   neutral  0.464066
# 1                  NaN  positive  0.941503
# 2  ð (2),â¤ï¸ (1)  positive  0.988165
# 3                  NaN  positive  0.726693
# 4                  NaN  positive  0.977583

# %% [markdown]
# ## Daily Average Sentiment

# %%
import pandas as pd

# Read data from file
file_path = 'https://raw.githubusercontent.com/Xintong1122/KDD/main/Data/message_with_sentiment.csv'  # Replace with your CSV file path
df = pd.read_csv(file_path)

# Check column names
print(df.columns)

# Define function to calculate sentiment score
def calculate_sentiment_score(label, score):
    if label == 'positive':
        return score
    elif label == 'negative':
        return -score
    else:
        return 0

# Calculate sentiment scores
df['Sentiment_Score'] = df.apply(lambda row: calculate_sentiment_score(row['Label'], row['Score']), axis=1)

# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date']).dt.date

# Calculate daily average sentiment scores
daily_sentiment = df.groupby('Date')['Sentiment_Score'].mean().reset_index()

# Define labeling
def label_sentiment(score):
    if score > 0.1:  # Define threshold for positive sentiment
        return 'positive'
    elif score < -0.1:  # Define threshold for negative sentiment
        return 'negative'
    else:
        return 'neutral'

# Assign labels to daily average sentiment scores
daily_sentiment['Label'] = daily_sentiment['Sentiment_Score'].apply(label_sentiment)

# Save results to a new CSV file
output_file_path = 'daily_sentiment_scores.csv'  # Replace with the path where you want to save it
daily_sentiment.to_csv(output_file_path, index=False)

# Output to verify
print(daily_sentiment.head())
# Out:
# Index(['AuthorID', 'Author', 'Date', 'Content', 'Attachments', 'Reactions',
#        'Label', 'Score'],
#       dtype='object')
#          Date  Sentiment_Score     Label
# 0  2024-01-01         0.871314  positive
# 1  2024-01-02         0.431091  positive
# 2  2024-01-03         0.070448   neutral
# 3  2024-01-04         0.208807  positive
# 4  2024-01-05         0.036255   neutral

# %%
import pandas as pd
from datetime import datetime, timedelta

# Define the path to the CSV file
file_path = 'https://raw.githubusercontent.com/Xintong1122/KDD/main/D/message_with_sentiment_1.csv'

# Read the CSV file
data = pd.read_csv(file_path)

# Ensure the date column is in datetime format
data['Date'] = pd.to_datetime(data['Date'], format='%m/%d/%Y %I:%M %p')

# Set the date range
start_date = datetime(2024, 1, 1)
end_date = datetime(2024, 6, 14)
date_range = pd.date_range(start_date, end_date)

# Check for missing dates
existing_dates = data['Date'].dt.date.unique()
missing_dates = set(date_range.date) - set(existing_dates)

print(f"Missing dates: {sorted(missing_dates)}")
# Out:
# Missing dates: [datetime.date(2024, 4, 28), datetime.date(2024, 5, 13)]

# %%
import pandas as pd
from datetime import datetime

# Define the path to the CSV file
file_path = 'https://raw.githubusercontent.com/Xintong1122/KDD/main/D/daily_sentiment_scores.csv'

# Read the CSV file
data = pd.read_csv(file_path)

# Ensure the date column is in datetime format
data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d')

# Fill in missing dates with data
missing_dates = [datetime(2024, 4, 28), datetime(2024, 5, 13)]
new_rows = [{'Date': date, 'Sentiment_Score': 0.0, 'Label': 'neutral'} for date in missing_dates]

# Use pd.concat to add new rows
data = pd.concat([data, pd.DataFrame(new_rows)], ignore_index=True)

# Keep the score rounded to 4 decimal places
data['Sentiment_Score'] = data['Sentiment_Score'].round(4)

# Sort by date
data = data.sort_values(by='Date')

# Save to a new CSV file
new_file_path = 'daily_processed_scores.csv'
data.to_csv(new_file_path, index=False)

# %% [markdown]
# # Figure

# %%
import pandas as pd
import plotly.graph_objects as go

# Read CSV file from GitHub
file_path = "https://raw.githubusercontent.com/Xintong1122/KDD/main/D/message_with_sentiment_1.csv"
data = pd.read_csv(file_path)

# Extract relevant columns
labels = ['positive', 'neutral', 'negative']

# Calculate the number of each sentiment label for LLM1
llm1_counts = [(data['Label'] == label).sum() for label in labels]

# Prepare text to display on each bar and set font settings
llm1_text = [f'{count}' for count in llm1_counts]

# Custom colors for sentiments in hexadecimal format
colors = {'positive': '#66c2a5', 'neutral': '#8da0cb', 'negative': '#fb8d62'}

# Plot bar chart for LLM1
fig = go.Figure(data=[
    go.Bar(name='LLM', x=labels, y=llm1_counts, text=llm1_text, textposition='auto', textfont_color='white', marker_color=[colors[label] for label in labels])
])

# Modify layout and style
fig.update_layout(
    font=dict(family="Times New Roman, Times, serif", size=14),
    xaxis_title='Sentiment Label',
    yaxis_title='Number',
    height=625,
    width=1000,
    title='Distribution of Sentiment Categories using LLM',
)

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8e7d8e44-b2b8-44b1-b995-6624bf248547" class="plotly-graph-div" style="height:625px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e7d8e44-b2b8-44b1-b995-6624bf248547")) {                    Plotly.newPlot(                        "8e7d8e44-b2b8-44b1-b995-6624bf248547",                        [{"marker":{"color":["#66c2a5","#8da0cb","#fb8d62"]},"name":"LLM","text":["1485","3361","667"],"textfont":{"color":"white"},"textposition":"auto","x":["positive","neutral","negative"],"y":[1485,3361,667],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay" ...

# %%
import pandas as pd
import plotly.express as px

# Read CSV file from GitHub
url = 'https://raw.githubusercontent.com/Xintong1122/KDD/main/D/2.csv'
df = pd.read_csv(url)

# Rename columns
df = df.rename(columns={
    'Sentiment_Score': 'LLM1',
})

# Plot line chart for LLM1
fig = px.line(df, x='Date', y='LLM1',
              labels={'value': 'Sentiment Score', 'variable': 'LLM Model'},
              title='Sentiment Scores over Time')

# Set line color to orange and style
fig.update_traces(line=dict(color='orange', width=2), selector=dict(mode='lines'))

# Update font style and axis annotations
fig.update_layout(
    font=dict(family="Times New Roman, Times, serif", size=12),
    xaxis=dict(title='Date(d)', tickformat='%b%d', tickfont=dict(size=12)),
    yaxis=dict(title='Sentiment Score', tickfont=dict(size=12)),
    legend=dict(title='LLM Model', title_font=dict(size=12)),
    height=625,
    width=1000,
    margin=dict(l=50, r=50, t=50, b=50),
)

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b65f72f8-f87b-4748-aec6-9e9084be63b4" class="plotly-graph-div" style="height:625px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b65f72f8-f87b-4748-aec6-9e9084be63b4")) {                    Plotly.newPlot(                        "b65f72f8-f87b-4748-aec6-9e9084be63b4",                        [{"hovertemplate":"Date=%{x}\u003cbr\u003eLLM1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"orange","dash":"solid","width":2},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2023-06-15","2023-06-16","2023-06-17","2023-06-18","2023-06-19","2023-06-20","2023-06-21","2023-06-22","2023-06-23","2023-06-24","2023-06-25","2023-06-26","2023-06-27","2023-06-28","2023-06-29","2023-06-30","2023-07-01","2023-07-02","2023-07-03","2023-07-04","2023-07-05","2023-07-06","2023-07-07","2023-07-08","2023-07-09","2023-07-10","2023-07-11","2023-07-12","2023-07-13","2023-07-14","2023-07-15","2023-07-16","2023-07-17","2023-07-18","2023-07-19","2023-07-20","2023-07-21","2023-07-22","2023-07-23","2023-07-24","2023-07-25","2023-07-26","2023-07-27","2023-07-28","2023-07-29","2023-07-30","2023-07-31","2023-08-01","2023-08-02","2023-08-03","2023-08-04","2023-08-05","2023-08-06","2023-08-07","2023-08-08","2023-08-09","2023-08-10","2023-08-11","2023-08-12","2023-08-13","2023-08-14","2023-08-15","2023-08-16","2023-08-17","2023-08-18","2023-08-19","2023-08-20","2023-08-21","2023-08-22","2023-08-23","2023-08-24","2023-08-25","2023-08-26","2023-08-27","2023-08-28","2023-08-29","2023-08-30","2023-08-31","2023-09-01","2023-09-02","2023-09-03","2023-09-04","2023-09-05","2023-09-06","2023-09-07","2023-09-08","2023-09-09","2023-09-10","2023-09-11","2023-09-12","2023-09-13","2023-09-14","2023-09-15","2023-09-16","2023-09-17","2023-09-18","2023-09-19","2023-09-20","2023-09-21","2023-09-22","2023-09-23","2023-09-24","2023-09-25","2023-09-26","2023-09-27","2023-09-28","2023-09-29","2023-09-30","2023-10-01","2023-10-02","2023-10-03","2023-10-04","2023-10-05","2023-10-06","2023-10-07","2023-10-08","2023-10-09","2023-10-10","2023-10-11","2023-10-12","2023-10-13","2023-10-14","2023-10-15","2023-10-16","2023-10-17","2023-10-18","2023-10-19","2023-10-20","2023-10-21","2023-10-22","2023-10-23","2023-10-24","2023-10-25","2023-10-26","2023-10-27","2023-10-28","2023-10-29","2023-10-30","2023-10-31","2023-11-01","2023-11-02","2023-11-03","2023-11-04","2023-11-05","2023-11-06","2023-11-07","2023-11-08","2023-11-09","2023-11-10","2023-11-11","2023-11-12","2023-11-13","2023-11-14","2023-11-15","2023-11-16","2023-11-17","2023-11-18","2023-11-19","2023-11-20","2023-11-21","2023-11-22","2023-11-23","2023-11-24","2023-11-25","2023-11-26","2023-11-27","2023-11-28","2023-11-29","2023-11-30","2023-12-01","2023-12-02","2023-12-03","2023-12-04","2023-12-05","2023-12-06","2023-12-07","2023-12-08","2023-12-09","2023-12-10","2023-12-11","2023-12-12","2023-12-13","2023-12-14","2023-12-15","2023-12-16","2023-12-17","2023-12-18","2023-12-19","2023-12-20","2023-12-21","2023-12-22","2023-12-23","2023-12-24","2023-12-25","2023-12-26","2023-12-27","2023-12-28","2023-12-29","2023-12-30","2023-12-31","2024-01-01","2024-01-02","2024-01-03","2024-01-04","2024-01-05","2024-01-06","2024-01-07","2024-01-08","2024-01-09","2024-01-10","2024-01-11","2024-01-12","2024-01-13","2024-01-14","2024-01-15","2024-01-16","2024-01-17","2024-01-18","2024-01-19","2024-01-20","2024-01-21","2024-01-22","2024-01-23","2024-01-24","2024-01-25","2024-01-26","2024-01-27","2024-01-28","2024-01-29","2024-01-30","2024-01-31","2024-02-01","2024-02-02","2024-02-03","2024-02-04","2024-02-05","2024-02-06","2024-02-07","2024-02-08","2024-02-09","2024-02-10","2024-02-11","2024-02-12","2024-02-13","2024- ...
